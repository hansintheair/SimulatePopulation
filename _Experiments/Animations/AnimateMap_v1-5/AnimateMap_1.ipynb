# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def data_gen(t=0):
    cnt = 0
    while cnt < 1000:
        cnt += 1
        t += 0.1
        yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)


def init():
    ax.set_ylim(-1.1, 1.1)
    ax.set_xlim(0, 10)
    del xdata[:]
    del ydata[:]
    line.set_data(xdata, ydata)
    return line,

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.grid()
xdata, ydata = [], []


def run(data):
    # update the data
    t, y = data
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 2*xmax)
        ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

ani = animation.FuncAnimation(fig, run, data_gen, blit=False, interval=10,
                              repeat=False, init_func=init)

from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img410cbd9c5a184113ae6b386c256c0c5a">
#     <br>
#     <input id="_anim_slider410cbd9c5a184113ae6b386c256c0c5a" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim410cbd9c5a184113ae6b386c256c0c5a.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim410cbd9c5a184113ae6b386c256c0c5a.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select410cbd9c5a184113ae6b386c256c0c5a" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img410cbd9c5a184113ae6b386c256c0c5a";
#     var slider_id = "_anim_slider410cbd9c5a184113ae6b386c256c0c5a";
#     var loop_select_id = "_anim_loop_select410cbd9c5a184113ae6b386c256c0c5a";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAHApJREFUeJzt3X9slfX9/vHrwLEqOqVloO1OiZRT\
# jm1pV+R0oH+4QqmddTtErVKCs6zgcY5kk8WNJmgjJsw6M3+WbDmB6HEmVGRbD9mkUn4cTZiuaaSL\
# s2jOQpH2tICFg0t1tFLP94+xc9ZvWz7d5Jz7vMvzkZj0ft/vu+c6r6CX5+7h1BaNRqMCAMAwU6wO\
# AADA/4ICAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQID\
# ABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAY\
# iQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGMlu\
# dYBEmT59upxOp9UxUsJnn32mq666yuoYKYFZxDGLOGYRd/ToUfX391sdY0ImbYFdd911am9vtzpG\
# SggGgyotLbU6RkpgFnHMIo5ZxLndbqsjTBi3EAEARqLAAABGosAAAEZKWoHV1tZq1qxZmj9//pjn\
# o9GofvzjH8vpdKqoqEjvvfde7Jzf71dubq5yc3Pl9/uTFRkAkMKSVmCrV69WS0vLuOd3796tUCik\
# UCgkn8+nhx56SJJ0+vRpbdq0SX/5y1/U1tamTZs2KRKJJCs2ACBFJa3Abr31VmVkZIx7PhAI6P77\
# 75fNZtPixYt15swZ9fX16c0331R5ebkyMjKUnp6u8vLyCxYhAODSkDI/AwuHw8rOzo4dOxwOhcPh\
# cdcBAJe2lPl7YNFodNSazWYbd30sPp9PPp9PkhSJRBQMBi9qRlMNDAwwi/OYRRyziGMWZkqZAnM4\
# HOru7o4d9/T0KCsrSw6HY8QfrJ6ennH/wqHX65XX65UkuVwu/mLiefwlzThmEccs4piFmVLmFqLH\
# 49Err7yiaDSqd999V9dee60yMzNVUVGhPXv2KBKJKBKJaM+ePaqoqLA6LgDAYkl7BbZy5UoFg0H1\
# 9/fL4XBo06ZN+uKLLyRJP/zhD1VZWak33nhDTqdT06ZN00svvSRJysjI0GOPPaaSkhJJUn19/QXf\
# DAIAuDQkrcC2b99+wfM2m01btmwZ81xtba1qa2sTEQsAYKiUuYUIAMB/gwIDABiJAgMAGIkCAwAY\
# iQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkCAwAYiQIDABiJAgMAGIkC\
# AwAYKWkF1tLSIpfLJafTqYaGhlHn169fr+LiYhUXF2vevHmaPn167NzUqVNj5zweT7IiAwBSWFJ+\
# I/Pw8LDWrVun1tZWORwOlZSUyOPxKD8/P7bn2WefjX394osv6tChQ7HjK6+8Uh0dHcmICgAwRFJe\
# gbW1tcnpdConJ0dpaWmqrq5WIBAYd//27du1cuXKZEQDABgqKQUWDoeVnZ0dO3Y4HAqHw2Pu/fjj\
# j9XV1aWlS5fG1s6ePSu3263Fixerubk54XkBAKkvKbcQo9HoqDWbzTbm3qamJlVVVWnq1KmxtWPH\
# jikrK0tHjhzR0qVLVVhYqLlz54661ufzyefzSZIikYiCweDFeQKGGxgYYBbnMYs4ZhHHLMyUlAJz\
# OBzq7u6OHff09CgrK2vMvU1NTdqyZcuItX/vzcnJUWlpqQ4dOjRmgXm9Xnm9XkmSy+VSaWnpRXoG\
# ZgsGg8ziPGYRxyzimIWZknILsaSkRKFQSF1dXRoaGlJTU9OY7yb86KOPFIlEdPPNN8fWIpGIBgcH\
# JUn9/f06ePDgiDd/AAAuTUl5BWa329XY2KiKigoNDw+rtrZWBQUFqq+vl9vtjpX
